# %%
import pandas as pd

# %%
df = pd.read_csv('/content/diabetes.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_915/3097418338.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('/content/diabetes.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %% [markdown]
# exploring dataset and multiple operations

# %%
#explore the dataset
'''
this is multiline comment.

'''
df.head()

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/281403043.py in <cell line: 0>()
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
df.head(11)

# %%
df.tail(11)

# %%
#to see the shape of dataset
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/3238976777.py in <cell line: 0>()
#       1 #to see the shape of dataset
# ----> 2 df.shape
#
# NameError: name 'df' is not defined

# %%
#to see the name of columns
df.columns

# %%
#to see the datatypes of the columns
df.dtypes

# %%
#general specifications of the dataset
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/628092169.py in <cell line: 0>()
#       1 #general specifications of the dataset
# ----> 2 df.info()
#
# NameError: name 'df' is not defined

# %%
#to see the statistical summary of the dataset
df.describe()

# %%
#to check the missing value
df.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/2525576164.py in <cell line: 0>()
#       1 #to check the missing value
# ----> 2 df.isnull()
#
# NameError: name 'df' is not defined

# %%
df.isnull().count()

# %%
# to check the duplicate values
df.duplicated()

# %%
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/1382667195.py in <cell line: 0>()
# ----> 1 df.duplicated().sum()
#
# NameError: name 'df' is not defined

# %%
df.duplicated().count()

# %%
#to count unique values per column
df.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/1447991829.py in <cell line: 0>()
#       1 #to count unique values per column
# ----> 2 df.nunique()
#
# NameError: name 'df' is not defined

# %%
#to check the invalid 0 valules(real missing data)
df[['Glucose','BloodPressure']] == 0

# %%
(df[['Glucose','BloodPressure']] == 0).sum()

# %%
(df[['Glucose','BloodPressure']] == 0).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/4292812139.py in <cell line: 0>()
# ----> 1 (df[['Glucose','BloodPressure']] == 0).count()
#
# NameError: name 'df' is not defined

# %%
#select a column
df['BMI']

# %%
 #to select multiple column
 df[['Age','BloodPressure']]

# %%
#filter rows by some condition
df[df['Age']>60]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/2619959777.py in <cell line: 0>()
#       1 #filter rows by some condition
# ----> 2 df[df['Age']>60]
#
# NameError: name 'df' is not defined

# %%
df[df['Age']>60].count()

# %%
#filter with multiple condition
df[(df['Age']>65) & (df['BMI']<30)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/4275641465.py in <cell line: 0>()
#       1 #filter with multiple condition
# ----> 2 df[(df['Age']>65) & (df['BMI']<30)]
#
# NameError: name 'df' is not defined

# %%
df[(df['Age']>65) & (df['Outcome']) == 1]

# %%
df[(df['Age']>65) & (df['Outcome']) == 1].count()

# %%
#access rows by index
df.iloc[1:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/3497314791.py in <cell line: 0>()
#       1 #access rows by index
# ----> 2 df.iloc[1:5]
#
# NameError: name 'df' is not defined

# %%
df.iloc[11:675]

# %%
df.loc[1:5]

# %%
#sorting and grouping
'''sort any data  using column'''


df.sort_values(by='Age')

# %%
#value count
df['Age'].value_counts()

# %%
#group by and agregate
df.groupby('Outcome').mean()

# %%
df.groupby('Outcome').agg('mean')

# %%
#statistics
df['BMI'].median()

# %%
df['BMI'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_915/2202321996.py in <cell line: 0>()
# ----> 1 df['BMI'].mean()
#
# NameError: name 'df' is not defined

# %%
#standard deviation
df['Age'].std()

# %%
#correa=lation matrix
df.corr()

# %%
#modificatoin of data
#add new column

df['BMI_category'] = pd.cut(df['BMI'], bins=[0, 18.5, 24.9, 29.9, float('inf')], labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# %%
df.head()

# %%
#replace invalid zero

df['Glucose'] = df['Glucose'].replace(0, df['Glucose'].mean())

# %%
df.head(20)

# %%
df['Insulin'] = df['Insulin'].replace(0, df['Insulin'].median())

# %%
df.head(20)

# %%
#histogram
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(df['Age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %%
plt.hist(df['Age'])
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()
